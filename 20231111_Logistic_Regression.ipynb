# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/guillaume/Desktop/GoMycode/Intelligence Artificielle/FichiersCsv/logistic_regression_dataset.csv')

# %%
df.head(30)
# Out:
#     id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0    0   64        2.0   F        YES         3.0     0.0                0
# 1    1   36        4.0   M         NO         0.0     0.0                0
# 2    2   46        1.0   F        YES        10.0     0.0                0
# 3    3   50        1.0   M        YES        20.0     0.0                0
# 4    4   64        1.0   F        YES        30.0     0.0                0
# 5    5   61        3.0   F         NO         0.0     0.0                0
# 6    6   61        1.0   M         NO         0.0     0.0                0
# 7    7   36        4.0   M        YES        35.0     0.0                0
# 8    8   41        2.0   F        YES        20.0     NaN                0
# 9    9   55        2.0   F         NO         0.0     0.0                0
# 10  10   61        1.0   F         NO         0.0     0.0                0
# ...

# %%
df['TenYearCHD'].value_counts()
# Out:
# 0.0    2879
# 1.0     511
# Name: TenYearCHD, dtype: int64

# %%
#pas assez d'équilibre dans la base de données : une facon et de doubler le nombre de données

# %%
df.isnull().sum()
# Out:
# id                   0
# age                  0
# education          105
# sex                  0
# is_smoking           0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD         848
# dtype: int64

# %%
df.count()
# Out:
# id                 4238
# age                4238
# education          4133
# sex                4238
# is_smoking         4238
# cigsPerDay         4209
# BPMeds             4185
# prevalentStroke    4238
# prevalentHyp       4238
# diabetes           4238
# totChol            4188
# sysBP              4238
# diaBP              4238
# BMI                4219
# heartRate          4237
# glucose            3850
# TenYearCHD         3390
# dtype: int64

# %%
#on supprime les lignes avec les valeurs manquantes
df = df.dropna(axis=0, subset = 'TenYearCHD')

# %%
df.isnull().sum()
# Out:
# id                   0
# age                  0
# education            0
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
# On va remplacer les valeurs manquantes
df['education'].describe()
# Out:
# count    3303.000000
# mean        1.970936
# std         1.019081
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         4.000000
# Name: education, dtype: float64

# %%
df['BPMeds'].describe()
# Out:
# count    3346.000000
# mean        0.029886
# std         0.170299
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: BPMeds, dtype: float64

# %%
#On va remplacer les valeurs par la moyenne sauf l'education que l'on va remplacer par la médiane
df['education'].fillna(df['education'].median(), inplace=True)
df['cigsPerDay'].fillna(df['cigsPerDay'].mean(), inplace=True)
df['BPMeds'].fillna(df['BPMeds'].median(), inplace=True)
df['totChol'].fillna(df['totChol'].mean(), inplace=True)
df['BMI'].fillna(df['BMI'].mean(), inplace=True)
df['heartRate'].fillna(df['heartRate'].mean(), inplace=True)
df['glucose'].fillna(df['glucose'].mean(), inplace=True)
# Out:
# /var/folders/m6/t912xmd176sgkbvdy2hcngqh0000gn/T/ipykernel_3249/3275657011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['education'].fillna(df['education'].median(), inplace=True)
# /var/folders/m6/t912xmd176sgkbvdy2hcngqh0000gn/T/ipykernel_3249/3275657011.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cigsPerDay'].fillna(df['cigsPerDay'].mean(), inplace=True)
# /var/folders/m6/t912xmd176sgkbvdy2hcngqh0000gn/T/ipykernel_3249/3275657011.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.isnull().sum()
# Out:
# id                 0
# age                0
# education          0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.count()
# Out:
# id                 3390
# age                3390
# education          3390
# sex                3390
# is_smoking         3390
# cigsPerDay         3390
# BPMeds             3390
# prevalentStroke    3390
# prevalentHyp       3390
# diabetes           3390
# totChol            3390
# sysBP              3390
# diaBP              3390
# BMI                3390
# heartRate          3390
# glucose            3390
# TenYearCHD         3390
# dtype: int64

# %%
df.head(10)
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
# 5   5   61        3.0   F         NO         0.0     0.0                0
# 6   6   61        1.0   M         NO         0.0     0.0                0
# 7   7   36        4.0   M        YES        35.0     0.0                0
# 8   8   41        2.0   F        YES        20.0     0.0                0
# 9   9   55        2.0   F         NO         0.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP        BMI  heartRate  \
# 0             0         0    221.0  148.0   85.0  25.794964       90.0
# ...

# %%
#il faut traiter les variables catégorielles
#Sex and isSmoking ne sont pas des variables catégorielles ordinales, on va donc utiliser one hot encoder
one_hot_sex = pd.get_dummies(df['sex'])
#drop the column has it now encoded
df = df.drop('sex', axis = 1)
#Join the encoded df
df = df.join(one_hot_sex)

one_hot_is_smoking = pd.get_dummies(df['is_smoking'])
df = df.drop('is_smoking', axis = 1)
df = df.join(one_hot_is_smoking)

# %%
df
# Out:
#         id  age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0        0   64        2.0         3.0     0.0                0             0
# 1        1   36        4.0         0.0     0.0                0             1
# 2        2   46        1.0        10.0     0.0                0             0
# 3        3   50        1.0        20.0     0.0                0             1
# 4        4   64        1.0        30.0     0.0                0             0
# ...    ...  ...        ...         ...     ...              ...           ...
# 3385  3385   60        1.0         0.0     0.0                0             0
# 3386  3386   46        1.0         0.0     0.0                0             0
# 3387  3387   44        3.0         3.0     0.0                0             1
# 3388  3388   60        1.0         0.0     0.0                0             1
# 3389  3389   54        3.0         0.0     0.0                0             0
#
# ...

# %%
#on supprime la valeur id qui n'a pas d'intérêt pour analyser notre dataset
df = df.drop(labels = 'id', axis=1)

# %%
#on renomme les deux dernières colonnes qui sont missleading
df = df.rename(columns={'NO': 'Is_Smoker_NO'})
df = df.rename(columns={'YES': 'Is_Smoker_YES'})

# %%
#on peut faire la matrice de correlation pour voir sil y a une corrélation
import seaborn

heatmap = seaborn.heatmap(data = df.corr(),annot=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16,10))
corr = df.corr()
sns.heatmap(corr, cmap = 'cividis', annot = True)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'education', 'cigsPerDay', 'BPMeds', 'prevalentStroke',
#        'prevalentHyp', 'diabetes', 'totChol', 'sysBP', 'diaBP', 'BMI',
#        'heartRate', 'glucose', 'TenYearCHD', 'F', 'M', 'Is_Smoker_NO',
#        'Is_Smoker_YES'],
#       dtype='object')

# %%
#Pour la matrice de corrélation, on ne peut pas faire l'étude avec les variables catégorielles
#On peut en revanche analyser les valeurs numériques
#On va d'abord lancer la regression sur toutes les variables numériques et catégorielles, puis on va relancer la regression sans les valeurs numériques qui sont les moins corrélées
#import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import metrics

#features extraction
x = df[['age', 'education','cigsPerDay','BPMeds', 'prevalentStroke',
       'prevalentHyp', 'diabetes', 'totChol', 'sysBP', 'diaBP', 'BMI',
       'heartRate', 'glucose', 'F', 'M', 'Is_Smoker_NO',
       'Is_Smoker_YES']]
y = df['TenYearCHD']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=30)  #splitting data with test size of 25%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
accuracy = accuracy_score(y_test, y_pred)
print(f'Validation Accuracy : {accuracy * 100:.2f}%')
# Out:
# Validation Accuracy : 83.37%
# /Users/guillaume/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)

#pour savoir si 0 est positif ou négatif, tout dépend de la facon dont on a défini la variable catégorielle sur le tableau initial
#Du résultat on arrive à prédire les true positif mais on ne sait pas dire avec certitude à un négatif qu'il n'est pas malade
# Out:
# <Axes: xlabel='Predicted', ylabel='Actual'>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
#metriques de performance sur la précision,recall et f1-score
#On voit qu il y a de loverfitting
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.83      1.00      0.91       703
#          1.0       0.75      0.04      0.08       145
#
#     accuracy                           0.83       848
#    macro avg       0.79      0.52      0.49       848
# weighted avg       0.82      0.83      0.77       848

# %%
#features extraction
x = df[['age','prevalentHyp', 'sysBP', 'diaBP', 'glucose', 'F', 'M', 'Is_Smoker_NO',
       'Is_Smoker_YES']]
y = df['TenYearCHD']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=30)  #splitting data with test size of 25%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
accuracy = accuracy_score(y_test, y_pred)
print(f'Validation Accuracy : {accuracy * 100:.2f}%')
# Out:
# Validation Accuracy : 83.14%
# /Users/guillaume/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <Axes: xlabel='Predicted', ylabel='Actual'>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
#metriques de performance sur la précision,recall et f1-score
#On voit qu il y a de loverfitting
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.99      0.91       703
#          1.0       0.56      0.06      0.11       145
#
#     accuracy                           0.83       848
#    macro avg       0.70      0.53      0.51       848
# weighted avg       0.79      0.83      0.77       848

# %%
#L'algorithme ne nous a pas permis de dire que les positifs étaient effectivement malades.
#le probleme cest que la répartition entre malades et non malades n'est pas la meme
#une des solutions est de dupliquer le nombre de données
